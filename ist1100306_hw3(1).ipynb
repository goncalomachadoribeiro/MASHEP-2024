# %% [markdown]
# <a href="https://colab.research.google.com/github/goncalomachadoribeiro/MASHEP/blob/main/ist1100306_hw3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Classification problem with HWW ATLAS Open data using Machine Learning
#
# In this exercise you are given 3 files with tabular data split by 3 sets, respectively:
#
#  * Set of events for training the ML classifier (data_train.csv)
#  * Set of events for validating the ML classifier (data_val.csv)
#  * Set of events for testing the ML classifier (data_test.csv)
#
# The data content is the same used for the ML class, i.e.
#
#  * there is a number of observables (mLL,pTLL, etc...);
#  * a label indicating the true class of each event (0=background, 1=signal) included as a variable in the data frame;
#  * an event weight to be used for training ("train_weight").

# %% [markdown]
# ## Load and inspect data
#
# * Open data files
# * Inspect contents
# * Plot variables

# %%
data_train = pd.read_csv("https://www.lip.pt/~rute/MASimHEP/HWW_csv_prep/data_train.csv")
data_val   = pd.read_csv("https://www.lip.pt/~rute/MASimHEP/HWW_csv_prep/data_val.csv")
data_test  = pd.read_csv("https://www.lip.pt/~rute/MASimHEP/HWW_csv_prep/data_test.csv")

data_train
# Out:
#        Unnamed: 0      mLL     ptLL   dPhi_LL  dPhiLLmet       MET        mt  \
# 0          147358  49.0513  61.2491  1.381790    3.02321   67.4356  128.3110
# 1            5771  19.9963  57.7996  0.699216    2.46491   61.4980  112.4800
# 2           76660  43.8206  96.2837  0.084119    2.31188   84.7958  165.3850
# 3          154078  49.4911  85.4053  1.037550    2.22171   93.4773  160.1300
# 4           73055  33.0773  60.7330  1.009950    2.83851   42.6602  100.6350
# ...           ...      ...      ...       ...        ...       ...       ...
# 64055        5014  44.2874  59.5597  0.489036    2.80323   39.1230   95.1650
# 64056      173819  22.4984  68.0981  0.636690    2.88861   91.2377  156.3870
# 64057      153656  22.7315  61.5826  0.317995    3.08785   63.8451  125.3620
# 64058      187006  42.2915  55.7519  0.391131    2.96568   29.7256   81.1042
# 64059       86364  13.6318  49.4293  0.531743    1.98964  104.7350  120.6850
#
#        goodjet_n  goodbjet_n  Lepton1_Pt  ...  Lepton2_Eta  Lepton2_E  \
# 0              0           0     47.4727  ...    -1.721170    88.8479
# 1              1           0     40.3348  ...     1.846730    67.4742
# 2              1           0     61.2737  ...     0.502883    39.6200
# 3              1           0     61.2571  ...    -0.131749    36.3402
# 4              1           0     40.1756  ...     0.329813    30.5285
# ...          ...         ...         ...  ...          ...        ...
# 64055          0           0     35.7962  ...     0.418980    27.8105
# 64056          0           0     42.8521  ...     2.259050   138.8700
# 64057          0           0     38.6547  ...    -2.249690   113.4920
# 64058          0           0     39.6714  ...    -0.463672    18.8450
# 64059          1           0     28.8712  ...    -1.122440    37.9320
#
#        Lepton2_Phi  Lepton2_charge  Lepton2_type     weight  process  label  \
# 0        -0.235791              -1            11   0.988994  diboson      0
# 1         2.171550               1            11  31.823900   signal      1
# 2        -0.597652              -1            11  25.705100   signal      1
# 3        -2.929180              -1            13   0.084681  diboson      0
# 4         2.296100               1            11  32.887200   signal      1
# ...            ...             ...           ...        ...      ...    ...
# 64055     1.029180               1            11   0.000000   signal      1
# 64056    -0.802207               1            13   0.981583  diboson      0
# 64057     2.326470              -1            13   1.192730  diboson      0
# 64058     2.831800              -1            13   1.180240  diboson      0
# 64059     2.865330              -1            13   0.967925    ttbar      0
#
#        scale_weight  train_weight
# 0          0.024622      0.000016
# 1          0.003327      0.000016
# 2          0.002687      0.000013
# 3          0.002108      0.000001
# 4          0.003438      0.000016
# ...             ...           ...
# 64055      0.000000      0.000000
# 64056      0.024438      0.000016
# 64057      0.029694      0.000020
# 64058      0.029383      0.000020
# 64059      0.089291      0.000060
#
# [64060 rows x 26 columns]

# %%
features = data_train.columns
features
# Out:
# Index(['Unnamed: 0', 'mLL', 'ptLL', 'dPhi_LL', 'dPhiLLmet', 'MET', 'mt',
#        'goodjet_n', 'goodbjet_n', 'Lepton1_Pt', 'Lepton1_Eta', 'Lepton1_E',
#        'Lepton1_Phi', 'Lepton1_charge', 'Lepton1_type', 'Lepton2_Pt',
#        'Lepton2_Eta', 'Lepton2_E', 'Lepton2_Phi', 'Lepton2_charge',
#        'Lepton2_type', 'weight', 'process', 'label', 'scale_weight',
#        'train_weight'],
#       dtype='object')

# %%
plot_features = ['mLL', 'ptLL', 'dPhi_LL', 'dPhiLLmet', 'MET', 'mt',
                 'Lepton1_Pt', 'Lepton1_Eta', 'Lepton1_E', 'Lepton1_Phi',
                 'Lepton2_Pt', 'Lepton2_Eta', 'Lepton2_E', 'Lepton2_Phi']

for feat in plot_features:

    #(We are filtering data signal out of the 99% quantile to get the bulk of the distribution and obtain decent axes limits...)
    bins = plt.hist(data_train.query(f'({feat} < {feat}.quantile(.99)) & (process=="signal")')[feat].values, bins=20, density=True, histtype='step', color='red', label='signal')
    plt.hist(data_train.query('process=="ttbar"')[feat].values, bins=bins[1], density=True, histtype='step', color='darkorange', label='ttbar')
    plt.hist(data_train.query('process=="diboson"')[feat].values, bins=bins[1], density=True, histtype='step', color='darkviolet', label='diboson')

    plt.xlabel(feat)
    plt.ylabel('Density \(a.u\)')
    plt.legend()
    #plt.yscale("log")
    plt.show()

# %% [markdown]
# ## Data pre-processing for training
#
# * Define training 'features'
# * Construct the inputs (x_train,x_val), weights (w_train,w_val) and target values (y_train,y_val) to train the classifier (in this step you obtain the exact same arrays as used in the ML class)

# %%
train_features = ['mLL', 'ptLL', 'dPhi_LL', 'dPhiLLmet', 'MET', 'mt', 'goodjet_n',
                 'goodbjet_n', 'Lepton1_Pt', 'Lepton1_Eta', 'Lepton1_E', 'Lepton1_Phi',
                 'Lepton1_charge', 'Lepton1_type', 'Lepton2_Pt', 'Lepton2_Eta',
                 'Lepton2_E', 'Lepton2_Phi', 'Lepton2_charge', 'Lepton2_type']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(data_train[train_features].values)

x_train = scaler.transform(data_train[train_features].values)
y_train = data_train['label'].values
w_train = data_train['train_weight'].values

x_val = scaler.transform(data_val[train_features].values)
y_val = data_val['label'].values
w_val = data_val['train_weight'].values

x_test = scaler.transform(data_test[train_features].values)
y_test = data_test['label'].values
w_test = data_test['train_weight'].values

print(f'Train sample x {len(x_train)} events (y {len(y_train)} events)')
print(f'Val   sample x {len(x_val)} events (y {len(y_val)} events)')
print(f'Test  sample x {len(x_test)} events (y {len(y_test)} events)')
# Out:
# Train sample x 64060 events (y 64060 events)
# Val   sample x 64060 events (y 64060 events)
# Test  sample x 64060 events (y 64060 events)

# %% [markdown]
# # Exercise 1: DNN - Deep Neural Network Classifier

# %%
from sklearn.metrics import roc_curve, roc_auc_score

from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
tf.random.set_seed(2)

# %% [markdown]
# ## 1.a) DNN Training
#
# Train a DNN with the hyperparameters below:
#
# * 3 layers with 80, 95, 70 nodes respectively
# * Learning rate of 8e-4
# * 100 training epochs and Early Stopping with patience 4

# %%
model = Sequential()

# The Input and the Hidden Layers as in the exercise
model.add(Dense(80, input_dim = x_train.shape[1], activation='relu'))
model.add(Dense(95, activation='relu'))
model.add(Dense(70, activation='relu'))

# The Output Layer
model.add(Dense(1, activation='sigmoid'))

# Compile the network
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=8e-4), weighted_metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                1680
#
#  dense_1 (Dense)             (None, 95)                7695
#
#  dense_2 (Dense)             (None, 70)                6720
#
#  dense_3 (Dense)             (None, 1)                 71
#
# =================================================================
# Total params: 16166 (63.15 KB)
# Trainable params: 16166 (63.15 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, sample_weight=w_train, validation_data=(x_val,y_val,w_val),
                       epochs=100, batch_size=1024, callbacks=EarlyStopping(patience=4))
# Out:
# Epoch 1/100
# 63/63 [==============================] - 2s 14ms/step - loss: 7.1293e-06 - accuracy: 0.5518 - val_loss: 6.9495e-06 - val_accuracy: 0.5903
# Epoch 2/100
# 63/63 [==============================] - 1s 8ms/step - loss: 6.8224e-06 - accuracy: 0.6238 - val_loss: 6.6378e-06 - val_accuracy: 0.6527
# Epoch 3/100
# 63/63 [==============================] - 1s 8ms/step - loss: 6.5401e-06 - accuracy: 0.6617 - val_loss: 6.3730e-06 - val_accuracy: 0.6751
# Epoch 4/100
# 63/63 [==============================] - 1s 8ms/step - loss: 6.3254e-06 - accuracy: 0.6759 - val_loss: 6.1920e-06 - val_accuracy: 0.6831
# Epoch 5/100
# 63/63 [==============================] - 0s 8ms/step - loss: 6.1891e-06 - accuracy: 0.6803 - val_loss: 6.0846e-06 - val_accuracy: 0.6882
# Epoch 6/100
# 63/63 [==============================] - 1s 8ms/step - loss: 6.1158e-06 - accuracy: 0.6821 - val_loss: 6.0324e-06 - val_accuracy: 0.6897
# Epoch 7/100
# 63/63 [==============================] - 0s 8ms/step - loss: 6.0769e-06 - accuracy: 0.6829 - val_loss: 6.0038e-06 - val_accuracy: 0.6907
# Epoch 8/100
# 63/63 [==============================] - 0s 8ms/step - loss: 6.0493e-06 - accuracy: 0.6864 - val_loss: 5.9822e-06 - val_accuracy: 0.6915
# Epoch 9/100
# 63/63 [==============================] - 0s 8ms/step - loss: 6.0285e-06 - accuracy: 0.6872 - val_loss: 5.9669e-06 - val_accuracy: 0.6925
# Epoch 10/100
# 63/63 [==============================] - 0s 7ms/step - loss: 6.0092e-06 - accuracy: 0.6893 - val_loss: 5.9571e-06 - val_accuracy: 0.6918
# Epoch 11/100
# 63/63 [==============================] - 0s 8ms/step - loss: 5.9932e-06 - accuracy: 0.6896 - val_loss: 5.9490e-06 - val_accuracy: 0.6915
# Epoch 12/100
# 63/63 [==============================] - 0s 8ms/step - loss: 5.9811e-06 - accuracy: 0.6916 - val_loss: 5.9339e-06 - val_accuracy: 0.6950
# Epoch 13/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.9705e-06 - accuracy: 0.6912 - val_loss: 5.9283e-06 - val_accuracy: 0.6947
# Epoch 14/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.9578e-06 - accuracy: 0.6934 - val_loss: 5.9191e-06 - val_accuracy: 0.6953
# Epoch 15/100
# 63/63 [==============================] - 0s 7ms/step - loss: 5.9533e-06 - accuracy: 0.6927 - val_loss: 5.9162e-06 - val_accuracy: 0.6967
# Epoch 16/100
# 63/63 [==============================] - 1s 10ms/step - loss: 5.9398e-06 - accuracy: 0.6945 - val_loss: 5.9178e-06 - val_accuracy: 0.6950
# Epoch 17/100
# 63/63 [==============================] - 1s 14ms/step - loss: 5.9348e-06 - accuracy: 0.6936 - val_loss: 5.9083e-06 - val_accuracy: 0.6968
# Epoch 18/100
# 63/63 [==============================] - 1s 14ms/step - loss: 5.9286e-06 - accuracy: 0.6950 - val_loss: 5.9049e-06 - val_accuracy: 0.6952
# Epoch 19/100
# 63/63 [==============================] - 1s 13ms/step - loss: 5.9195e-06 - accuracy: 0.6953 - val_loss: 5.9102e-06 - val_accuracy: 0.6947
# Epoch 20/100
# 63/63 [==============================] - 1s 15ms/step - loss: 5.9166e-06 - accuracy: 0.6958 - val_loss: 5.9008e-06 - val_accuracy: 0.6978
# Epoch 21/100
# 63/63 [==============================] - 1s 9ms/step - loss: 5.9087e-06 - accuracy: 0.6956 - val_loss: 5.8981e-06 - val_accuracy: 0.6991
# Epoch 22/100
# 63/63 [==============================] - 0s 8ms/step - loss: 5.9039e-06 - accuracy: 0.6959 - val_loss: 5.8981e-06 - val_accuracy: 0.6968
# Epoch 23/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8987e-06 - accuracy: 0.6968 - val_loss: 5.8961e-06 - val_accuracy: 0.6978
# Epoch 24/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8930e-06 - accuracy: 0.6975 - val_loss: 5.8962e-06 - val_accuracy: 0.6976
# Epoch 25/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8878e-06 - accuracy: 0.6967 - val_loss: 5.8972e-06 - val_accuracy: 0.6989
# Epoch 26/100
# 63/63 [==============================] - 0s 8ms/step - loss: 5.8866e-06 - accuracy: 0.6988 - val_loss: 5.8926e-06 - val_accuracy: 0.6981
# Epoch 27/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8793e-06 - accuracy: 0.6997 - val_loss: 5.9015e-06 - val_accuracy: 0.6955
# Epoch 28/100
# 63/63 [==============================] - 0s 8ms/step - loss: 5.8772e-06 - accuracy: 0.6983 - val_loss: 5.8902e-06 - val_accuracy: 0.6985
# Epoch 29/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8697e-06 - accuracy: 0.6986 - val_loss: 5.8850e-06 - val_accuracy: 0.6984
# Epoch 30/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8654e-06 - accuracy: 0.6996 - val_loss: 5.8890e-06 - val_accuracy: 0.6985
# Epoch 31/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8619e-06 - accuracy: 0.7003 - val_loss: 5.8869e-06 - val_accuracy: 0.6982
# Epoch 32/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8594e-06 - accuracy: 0.7000 - val_loss: 5.8848e-06 - val_accuracy: 0.6985
# Epoch 33/100
# 63/63 [==============================] - 1s 9ms/step - loss: 5.8551e-06 - accuracy: 0.6998 - val_loss: 5.8877e-06 - val_accuracy: 0.6973
# Epoch 34/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8520e-06 - accuracy: 0.6990 - val_loss: 5.8856e-06 - val_accuracy: 0.6986
# Epoch 35/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8475e-06 - accuracy: 0.7004 - val_loss: 5.8853e-06 - val_accuracy: 0.6989
# Epoch 36/100
# 63/63 [==============================] - 1s 8ms/step - loss: 5.8476e-06 - accuracy: 0.7002 - val_loss: 5.8908e-06 - val_accuracy: 0.6987

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
y_train_pred = model.predict(x_train)
y_val_pred = model.predict(x_val)

bins = plt.hist(y_train_pred, bins=100, density=True, histtype='step', label='train')
plt.hist(y_val_pred, bins=bins[1], density=True, histtype='step', label='validation')

plt.xlabel('DNN output')
plt.legend(loc='upper left')
plt.show()
# Out:
# 2002/2002 [==============================] - 4s 2ms/step
# 2002/2002 [==============================] - 3s 1ms/step

# %% [markdown]
# ## 1.b) Evaluate the DNN
#
# * Plot the DNN output for signal and background and the Receiver Operating Characteristic (ROC) curve.
# * What is the ROC Area Under the Curve (AUC)?

# %%
bins = plt.hist(y_train_pred[np.where(y_train == 1)], bins=100, density=True, histtype='step', label='signal train')
plt.hist(y_val_pred[np.where(y_val == 1)], bins=bins[1], density=True, histtype='step', label='signal val')

plt.hist(y_train_pred[np.where(y_train == 0)], bins=100, density=True, histtype='step', label='bkg train')
plt.hist(y_val_pred[np.where(y_val == 0)], bins=bins[1], density=True, histtype='step', label='bkg val')

plt.xlabel('DNN output')
plt.legend(loc='upper left')
plt.show()

# %%
fpr, tpr, _ = roc_curve(y_val, y_val_pred)
auc = roc_auc_score(y_val, y_val_pred)
plt.plot(fpr,tpr,label=f'AUC {auc:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
print(f'The AUC is {auc:.4f}')
# Out:
# The AUC is 0.7460

# %% [markdown]
# # Exercise 2: RF - Random Forest Classifier

# %% [markdown]
# ## 2.a) RF Training
#
# Train a Random Forest Classifier with the hyperparameters below:
#
# * Maximum depth of 3
# * 40 decision trees (estimators)
#
# **HINT:** The method to retreive the class prediction from the classifier for an input set of data x
#
# ```
# predict_proba(x)
# ```
# returns the probabilities of classification according to each class (0 or 1), such that
#
# ```
# predict_proba(x)[:,0] # class-0 probability
# predict_proba(x)[:,1] # class-1 probability
# ```

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(max_depth=3, n_estimators = 40)
classifier.fit(x_train, y_train, sample_weight = w_train)
score = classifier.score(x_test, y_test)

pred_train = classifier.predict_proba(x_train)
pred_val = classifier.predict_proba(x_val)

sig_pred_train = pred_train[:, 1]
sig_pred_val = pred_val[:,1]

# %% [markdown]
# ## 2.b) Evaluate the RF
#
# * Plot the classifier output for signal and background and the Receiver Operating Characteristic (ROC) curve.
# * What is the ROC Area Under the Curve (AUC)?

# %%
bins = plt.hist(sig_pred_train[np.where(y_train == 1)], bins=100, density=True, histtype='step', color='blue', label='signal train', range=(0,1))
plt.hist(sig_pred_val[np.where(y_val == 1)], bins=bins[1], density=True, histtype='step', color='red', label='signal validation', range=(0,1))
plt.hist(sig_pred_train[np.where(y_train == 0)], bins=100, density=True, histtype='step', label='bkg train', range=(0,1))
plt.hist(sig_pred_val[np.where(y_val == 0)], bins=bins[1], density=True, histtype='step', label='bkg val', range=(0,1))
plt.xlabel('RF')
plt.legend()
plt.show()

fpr, tpr, _ = roc_curve(y_val, sig_pred_val)
auc = roc_auc_score(y_val, sig_pred_val)
plt.plot(fpr, tpr, label=f'AUC = {auc:.4f}')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend()
plt.show()

# %% [markdown]
# # Exercise 3: DNN versus RF
#
# Which method (DNN or Random Forest) has the best classification performance? Are these results in agreement with your expectations? Explain why.

# %% [markdown]
# Answer: Firstly, one must understand the two methods, DNN and Random Forest. A random forest is a collection of tree learners each trained on a bootstrap sample of the training data (Lalchand, Vidhi. "Extracting more from boosted decision trees: A high energy physics case study." arXiv preprint arXiv:2001.06033 (2020).), thus it combines the outputs of different trees to obtain a result. As such, it is less prone to overfitting (https://dataaspirant.com/random-forest-algorithm-machine-learing/). On the other hand, DNN is  capable of highly non-linear representations of the data. One would expect that the DNN would have a better classification performance, due to the fact that it can, in principle, model any function. However, one should point out that RF is less time-consuming with larger datasets, since we can use parallelization, and it is more resistent to overfitting. In order to compare these two methods, we computed in the previous questions the ROC AUC, which can be used as a performance measurement, since it tells how much model is capable of distinguishing between classes (Narkhede, Sarang. "Understanding auc-roc curve." Towards data science 26.1 (2018): 220-227.). Since the DNN presents a higher value, our expectation is met.
